# %%
#Import libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure

# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(12,8)  #adjust configuration of plot we will create

#lets import the data 
df= pd.read_csv(r'C:\Users\Fares\Desktop\movies.csv')

# %%
#let's look at the data
df
# Out:
#                                                 name rating      genre  year
# 0                                        The Shining      R      Drama  1980  \
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#checking NUll values , the percentage by column
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print (col, pct_missing)
# Out:
# name 0.0
# rating 0.010041731872717789
# genre 0.0
# year 0.0
# released 0.0002608242044861763
# score 0.0003912363067292645
# votes 0.0003912363067292645
# director 0.0
# writer 0.0003912363067292645
# star 0.00013041210224308815
# country 0.0003912363067292645
# budget 0.2831246739697444
# gross 0.02464788732394366
# company 0.002217005738132499
# runtime 0.0005216484089723526

# %%
# lets replace every nan with 0 
df = df.fillna(0)

# %%
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print (col, pct_missing)
# Out:
# name 0.0
# rating 0.0
# genre 0.0
# year 0.0
# released 0.0
# score 0.0
# votes 0.0
# director 0.0
# writer 0.0
# star 0.0
# country 0.0
# budget 0.0
# gross 0.0
# company 0.0
# runtime 0.0

# %%
#looking at data types of columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.budget
# Out:
# 0       19000000.0
# 1        4500000.0
# 2       18000000.0
# 3        3500000.0
# 4        6000000.0
#            ...
# 7663        7000.0
# 7664           0.0
# 7665       58750.0
# 7666       15000.0
# 7667           0.0
# Name: budget, Length: 7668, dtype: float64

# %%
df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')
df['votes']=df['votes'].astype('int64')
df['runtime']=df['runtime'].astype('int64')

# %%
#looking at the changes, we eliminated every .0 by converting the data type to integer
df
# Out:
#                                                 name rating      genre  year
# 0                                        The Shining      R      Drama  1980  \
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
#lets sort values by gross
df.sort_values(by='gross',ascending=False)
# Out:
#                                             name rating    genre  year
# 5445                                      Avatar  PG-13   Action  2009  \
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score    votes        director
# ...

# %%
#scatter plot with budget VS gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# %%
#plot using seaborn , Budget vs Gross
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#lets see coorelations with only numeric numbers #using Pearson which is the default method
df.select_dtypes(include=['number']).corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
#we are looking at a good correlation 0.75 between Budget and Gross, 
#we also have a good coorelation between Gross and Votes

# %%
#lets run it with another method: Spearman

# %%
df.select_dtypes(include=['number']).corr(method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097757  0.468107  0.291152  0.314681  0.141805
# score    0.097757  1.000000  0.428810 -0.007002  0.133564  0.399868
# votes    0.468107  0.428810  1.000000  0.604693  0.752550  0.289359
# budget   0.291152 -0.007002  0.604693  1.000000  0.716816  0.246941
# gross    0.314681  0.133564  0.752550  0.716816  1.000000  0.257478
# runtime  0.141805  0.399868  0.289359  0.246941  0.257478  1.000000

# %%
#Close results with the two methods, we actually got gross and votes have more corellation with this method. 
#Good Correlation between gross and budget , gross and votes

# %%
#lets see it in a better way with heat map
Coorelation_matrix= df.select_dtypes(include=['number']).corr()
sns.heatmap(Coorelation_matrix, annot=True)
plt.title('Correlation matrix for numeric features')
plt.xlabel('movie feautures')
plt.ylabel('movie feautures')

plt.show()

# %%
#lets numerize data, we have 'country','name','rating','genre'... a few that we should numerize to see correlation
df_num= df

# %%
# Convert all object columns to category and apply label encoding
for col_name in df_num.columns:
    if (df_num[col_name].dtype == 'object'):
        df_num[col_name] = df_num[col_name].astype('category').cat.codes

# %%
df_num
# Out:
#       name  rating  genre  year  released  score    votes  director  writer
# 0     6587       7      6  1980      1706    8.4   927000      2589    4015  \
# 1     5573       7      1  1980      1493    5.8    65000      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000      1111    2568
# 3      286       5      4  1980      1493    7.7   221000      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000      1054     522
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36       774    2615
# 7665  4717       0      6  2020       194    5.7       29      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7      2165    3345
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year
# 0                                        The Shining      R      Drama  1980  \
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
correlation_matrix= df_num.corr()
correlation_matrix
# Out:
#               name    rating     genre      year  released     score
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377  \
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross     0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186012
# ...

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.title("coorelation matrix")
plt.show()

# %%
#votes and budget have the highest coorelation to Gross earnings
# other feautures have low correlation
